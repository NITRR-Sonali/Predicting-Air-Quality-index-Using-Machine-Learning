# %% [markdown]
# Importing the dependencies
#
# ```
# # This is formatted as code
# ```

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Data Collection and processing

# %%
# loading csv file to pandas data frame
air_qualitydata = pd.read_csv('/content/AirQualityUCI.csv')

# %%
# printing first 5 row of data frame
air_qualitydata.head()
# Out:
#   Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;  \
# 0                              10/03/2004;18.00.00;2
# 1                   10/03/2004;19.00.00;2;1292;112;9
# 2                              10/03/2004;20.00.00;2
# 3                              10/03/2004;21.00.00;2
# 4                              10/03/2004;22.00.00;1
#
#                       Unnamed: 1                        Unnamed: 2 Unnamed: 3  \
# 0                  6;1360;150;11  9;1046;166;1056;113;1692;1268;13       6;48
# 1  4;955;103;1174;92;1559;972;13                              3;47        7;0
# 2                    2;1402;88;9   0;939;131;1140;114;1555;1074;11       9;54
# 3                    2;1376;80;9   2;948;172;1092;122;1584;1203;11       0;60
# 4                    6;1272;51;6   5;836;131;1205;116;1490;1110;11       2;59
#
#   Unnamed: 4 Unnamed: 5
# 0        9;0     7578;;
# 1     7255;;        NaN
# 2        0;0     7502;;
# ...

# %% [markdown]
# ALl vlaue are seperated by ';' Few column have comma in place of decimal

# %%
# loading csv file to pandas data frame
air_qualitydata = pd.read_csv('/content/AirQualityUCI.csv' , sep = ';' , decimal = ',')

# %%
# printing first 5 row of data frame
air_qualitydata.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH  Unnamed: 15 ,,,,,
# 0  13.6  48.9  0.7578          NaN   NaN
# ...

# %%
# removing last 2 column
air_qualitydata = air_qualitydata.iloc[:, :-2]

# %%
# printing first 5 row of data frame
air_qualitydata.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# ...

# %%
air_qualitydata.tail()
# Out:
#      Date Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 9466  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9467  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9468  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9469  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9470  NaN  NaN     NaN          NaN       NaN       NaN            NaN
#
#       NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)   T  RH  AH
# 9466      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9467      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9468      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9469      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9470      NaN           NaN      NaN           NaN          NaN NaN NaN NaN

# %%
air_qualitydata.shape
# Out:
# (9471, 15)

# %%
air_qualitydata.loc[[9356]]
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 9356  04/04/2005  14.00.00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH
# 9356        816.0  28.5  13.1  0.5028

# %% [markdown]
# 9356 are the last row value of a dataframe and rest row are containing the null value

# %%
# first 9357 row alone
air_qualitydata = air_qualitydata.head(9357)

# %%
air_qualitydata.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# ...

# %%
air_qualitydata.tail()
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 9352  04/04/2005  10.00.00     3.1       1314.0    -200.0      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0    -200.0      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0    -200.0      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0    -200.0       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9352         1101.0    472.0         539.0    190.0        1374.0
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH
# 9352       1729.0  21.9  29.3  0.7568
# 9353       1269.0  24.3  23.7  0.7119
# 9354       1092.0  26.9  18.3  0.6406
# ...

# %%
air_qualitydata.shape
# Out:
# (9357, 15)

# %%
# getting info of datasets
air_qualitydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
# dtypes: float64(13), object(2)
# memory usage: 1.1+ MB

# %%
# checking numbe of nill value in data frame
air_qualitydata.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %% [markdown]
# This shows that there are no missing values in a data frame. But the actual missing value are tagged "-200"
# This is described in UCI repository documentation

# %%
#counting number of times-200 appear in the data
air_qualitydata.isin(["-200"]).sum(axis =0)
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %% [markdown]
# **Handling the missing values**

# %% [markdown]
# convert all -200 to Nan

# %%
# the replace the Nan with mean of specific column
air_qualitydata  =air_qualitydata.replace(to_replace = -200, value = np.NaN)

# %%
air_qualitydata.isnull().sum()
# Out:
# Date                0
# Time                0
# CO(GT)           1683
# PT08.S1(CO)       366
# NMHC(GT)         8443
# C6H6(GT)          366
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# dtype: int64

# %% [markdown]
# This show actua lnumber of missing values

# %%
air_qualitydata.tail()
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 9352  04/04/2005  10.00.00     3.1       1314.0       NaN      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0       NaN      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0       NaN      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0       NaN       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0       NaN      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9352         1101.0    472.0         539.0    190.0        1374.0
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH
# 9352       1729.0  21.9  29.3  0.7568
# 9353       1269.0  24.3  23.7  0.7119
# 9354       1092.0  26.9  18.3  0.6406
# ...

# %%
air_qualitydata.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-b532808b10ff> in <cell line: 1>()
# ----> 1 air_qualitydata.mean()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11333         **kwargs,
#   11334     ):
# > 11335         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11336         if isinstance(result, Series):
#   11337             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11990         **kwargs,
#   11991     ) -> Series | float:
# > 11992         return self._stat_function(
#   11993             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11994         )
#
# ...

# %%
air_qualitydata.mean()
air_qualitydata.mean()
air_qualitydata = air_qualitydata.fillna(air_qualitydata.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-fa643199bde0> in <cell line: 1>()
# ----> 1 air_qualitydata.mean()
#       2 air_qualitydata.mean()
#       3 air_qualitydata = air_qualitydata.fillna(air_qualitydata.mean())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11333         **kwargs,
#   11334     ):
# > 11335         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11336         if isinstance(result, Series):
#   11337             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11990         **kwargs,
#   11991     ) -> Series | float:
# > 11992         return self._stat_function(
# ...

# %%
air_qualitydata.tail()
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 9352  04/04/2005  10.00.00     3.1       1314.0       NaN      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0       NaN      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0       NaN      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0       NaN       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0       NaN      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9352         1101.0    472.0         539.0    190.0        1374.0
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH
# 9352       1729.0  21.9  29.3  0.7568
# 9353       1269.0  24.3  23.7  0.7119
# 9354       1092.0  26.9  18.3  0.6406
# ...

# %%
air_qualitydata.isnull().sum()
# Out:
# Date                0
# Time                0
# CO(GT)           1683
# PT08.S1(CO)       366
# NMHC(GT)         8443
# C6H6(GT)          366
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# dtype: int64

# %% [markdown]
# # Two task perform on a dataset
# #1. Forecasting
# #2.Regression

# %% [markdown]
# #https://mirahari.github.io/boston/
# # boston value datasets

# %% [markdown]
# # forecasting with FB prophet algorithm
# https://facebook.github.io/prophet/docs/quick_start.html

# %%
# forecasting with FB prophet algorithm
#converting date format from DD/MM/YYYY to YYYY/MM/DD
date_info = pd.to_datetime(air_qualitydata['Date'])
print(date_info)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-cc04fdcb3454> in <cell line: 3>()
#       1 # forecasting with FB prophet algorithm
#       2 #converting date format from DD/MM/YYYY to YYYY/MM/DD
# ----> 3 date_info = pd.to_datetime(air_qualitydata['Date'])
#       4 print(date_info)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1106                 result = arg.tz_localize("utc")
#    1107     elif isinstance(arg, ABCSeries):
# -> 1108         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1109         if not cache_array.empty:
#    1110             result = arg.map(cache_array)
#
# ...

# %%
time_info = air_qualitydata['Time']

# %%
print(time_info)

# %%
print(type(time_info))
print(type(date_info))

# %%
# Combining two series to a pandas of dataframe
date_time = pd.concat([date_info , time_info] , axis = 1)

# %%
date_time.head()

# %%
date_time.shape()

# %%
# Cmbining date and time
date_time['ds'] = date_time['Date'] + ''+ date_time['Time'].astype(str)

# %%
date_time.head()

# %%
date_time.info()

# %% [markdown]
# We have to convert ds from object datatype to date time format

# %%
data = pd.dataframe()

# %%
data['ds'] = pd.to_datetime(date_time['ds'])

# %%
data.head()

# %%
data['y'] = air_qualitydata['RH']

# %%
data.head()

# %%
! pip install prophet

# %%
from prophet import Prophet

# %%
# Training hte prophet model
model = Prophet()
model.fit(data)

# %%
future = model.make_future_dataframe(periods = 365 , freq = 'H')
future.tail()

# %%
forecasr = model.predict(future)
forecast['ds', 'yhat' ,'yhat_lower' ,'yhat_upper'].tail()

# %%
fig1 = model.plot(forecast)

# %%
fig2 = model.plot_components(forecast)
